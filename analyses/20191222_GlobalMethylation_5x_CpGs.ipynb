# %%
CalculateGlobalMethylation_5x0.75group_CpGs

# %%
cd 20191222
# Out:
# /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/20191222

# %%
# !ls *5xmerg_allc.tsv
# Out:
# EPI-103_S27_L005_5xmerg_allc.tsv EPI-181_S16_L003_5xmerg_allc.tsv
# EPI-104_S28_L005_5xmerg_allc.tsv EPI-182_S17_L003_5xmerg_allc.tsv
# EPI-111_S29_L005_5xmerg_allc.tsv EPI-184_S18_L003_5xmerg_allc.tsv
# EPI-113_S30_L005_5xmerg_allc.tsv EPI-185_S19_L003_5xmerg_allc.tsv
# EPI-119_S31_L005_5xmerg_allc.tsv EPI-187_S20_L003_5xmerg_allc.tsv
# EPI-120_S32_L005_5xmerg_allc.tsv EPI-188_S21_L003_5xmerg_allc.tsv
# EPI-127_S33_L005_5xmerg_allc.tsv EPI-193_S22_L003_5xmerg_allc.tsv
# EPI-128_S34_L005_5xmerg_allc.tsv EPI-194_S23_L003_5xmerg_allc.tsv
# EPI-135_S35_L005_5xmerg_allc.tsv EPI-199_S24_L003_5xmerg_allc.tsv
# EPI-136_S36_L005_5xmerg_allc.tsv EPI-200_S25_L003_5xmerg_allc.tsv
# EPI-143_S37_L005_5xmerg_allc.tsv EPI-205_S26_L004_5xmerg_allc.tsv
# EPI-145_S38_L005_5xmerg_allc.tsv EPI-206_S27_L004_5xmerg_allc.tsv
# EPI-151_S2_L002_5xmerg_allc.tsv  EPI-208_S28_L004_5xmerg_allc.tsv
# EPI-152_S3_L002_5xmerg_allc.tsv  EPI-209_S29_L004_5xmerg_allc.tsv
# ...

# %%
# %%bash
# for f in *_5xmerg_allc.tsv
# do
# cat ${f} | \
# awk '{MCsum +=$5;Csum+=$6}END{print MCsum,Csum, (MCsum/Csum)*100}'
# done
# Out:
# 3189592 11707277 27.2445
# 6514200 19586601 33.2585
# 5096495 17271921 29.5074
# 4875483 16374330 29.7752
# 4969831 19331557 25.7084
# 4636325 15804772 29.335
# 4057457 13546037 29.9531
# 4738349 15785406 30.0173
# 5652416 17452955 32.3866
# 4748036 16912204 28.0746
# 3463288 11368937 30.4627
# 4722068 15675355 30.1242
# 3479374 9855749 35.303
# 4605020 12383384 37.1871
# 2817728 8269254 34.0748
# 2835732 8095871 35.0269
# 1480367 4287753 34.5255
# 4141492 12023991 34.4436
# 1907097 5992743 31.8234
# 1907662 6159924 30.9689
# 3303371 9941439 33.2283
# 2708228 8195285 33.0462
# 2462003 7263569 33.8952
# 2795632 9063870 30.8437
# 3614380 11111759 32.5275
# 4955419 15558347 31.8505
# 4524337 12769519 35.4308
# 5219193 16269675 32.0793
# 2259187 6929923 32.6005
# 451527 1794305 25.1645
# 3797230 9825102 38.6483
# 1801803 5807741 31.0242
# 3472932 9922104 35.002
# 5639100 15141780 37.242
# 1466428 3860163 37.9888
# 3416934 9066703 37.6866
# 1394657 4014542 34.7401
# ...

# %%
# %%bash
# for f in *_5xmerg_allc.tsv
# do
# cat ${f} | \
# awk '{MCsum +=$5;Csum+=$6}END{print MCsum,Csum, (MCsum/Csum)*100}' |\
# echo $(basename ${f} _5xmerg_allc.tsv) -
# done
# Out:
# awk: syntax error at source line 1
#  context is
# 	{MCsum +=$5;Csum+=$6}END{print $(basename >>>  ${ <<<
# awk: illegal statement at source line 1
# awk: illegal statement at source line 1
# awk: syntax error at source line 1
#  context is
# 	{MCsum +=$5;Csum+=$6}END{print $(basename >>>  ${ <<<
# awk: illegal statement at source line 1
# awk: illegal statement at source line 1
# awk: syntax error at source line 1
#  context is
# 	{MCsum +=$5;Csum+=$6}END{print $(basename >>>  ${ <<<
# awk: illegal statement at source line 1
# awk: illegal statement at source line 1
# awk: syntax error at source line 1
#  context is
# 	{MCsum +=$5;Csum+=$6}END{print $(basename >>>  ${ <<<
# awk: illegal statement at source line 1
# awk: illegal statement at source line 1
# awk: syntax error at source line 1
#  context is
# 	{MCsum +=$5;Csum+=$6}END{print $(basename >>>  ${ <<<
# awk: illegal statement at source line 1
# awk: illegal statement at source line 1
# awk: syntax error at source line 1
# ...

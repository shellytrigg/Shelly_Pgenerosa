# %%
#This notebook is to call DMRs for all ambient samples 
# but including a minimum threshold of 3 samples/treatment group for calling DMRs
#which was not included previously

# %%
pwd
# Out:
# '/Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses'

# %%
# For table S1, compare day 0, day 10, day 135, and day 145

# %%
# %%bash
#
# methylpy DMRfind \
# --allc-files /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-41_S38.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-42_S39.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-43_S40.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-44_S41.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-119_S31.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-120_S32.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-135_S35.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-136_S36.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-151_S2.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-152_S3.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-153_S4.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-154_S5.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-181_S16.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-182_S17.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-184_S18.tsv.gz \
# /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/allc_EPI-185_S19.tsv.gz \
# --samples EPI-41 EPI-42 EPI-43 EPI-44 EPI-119 EPI-120 EPI-135 EPI-136 EPI-151 EPI-152 EPI-153 EPI-154 EPI-181 EPI-182 EPI-184 EPI-185 \
# --mc-type "CGN" \
# --num-procs 8 \
# --min-cov 5 \
# --output-prefix /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/amb_AllTimes_DMR250bp_MCmax25_cov5x_clst3 \
# --mc-max-dist 25 \
# --dmr-max-dist 250 \
# --min-num-dms 3 \
# --sample-category D0 D0 D0 D0 D10 D10 D10 D10 D135 D135 D135 D135 D145 D145 D145 D145 \
# --min-cluster 3
# Out:
# Filtering allc files using 8 node(s).
# Mon Sep  9 22:14:21 2019
#
# Splitting allc files for chromosome PGA_scaffold1__77_contigs__length_89643857
# Mon Sep  9 22:18:22 2019
#
# Running rms tests for chromosome PGA_scaffold1__77_contigs__length_89643857
# Mon Sep  9 22:18:26 2019
#
# Splitting allc files for chromosome PGA_scaffold2__36_contigs__length_69596280
# Mon Sep  9 22:18:26 2019
#
# Ran 5761 root mean square tests. Results in /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/amb_AllTimes_DMR250bp_MCmax25_cov5x_clst3_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_6.tsv
# Ran 6598 root mean square tests. Results in /Volumes/web/metacarcinus/Pgenerosa/analyses/20190822/amb_AllTimes_DMR250bp_MCmax25_cov5x_clst3_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_7.tsv
# Running rms tests for chromosome PGA_scaffold2__36_contigs__length_69596280
# Mon Sep  9 22:19:18 2019
#
# ...

# %%
#change

# %%
cd ~/Documents/GitHub/Shelly_Pgenerosa/analyses/20200311_compare_DMRfind_output/
# Out:
# /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/20200311_compare_DMRfind_output

# %%
# !cp /Volumes/web/metacarcinus/Pgenerosa/analyses/20191222/EPI*.tsv /Users/strigg/Desktop/20200311_DMRfind/

# %%
# !ls /Users/strigg/Desktop/20200311_DMRfind
# Out:
# EPI-103_S27_L005_5xmerg_allc.tsv EPI-181_S16_L003_5xmerg_allc.tsv
# EPI-104_S28_L005_5xmerg_allc.tsv EPI-182_S17_L003_5xmerg_allc.tsv
# EPI-111_S29_L005_5xmerg_allc.tsv EPI-184_S18_L003_5xmerg_allc.tsv
# EPI-113_S30_L005_5xmerg_allc.tsv EPI-185_S19_L003_5xmerg_allc.tsv
# EPI-119_S31_L005_5xmerg_allc.tsv EPI-187_S20_L003_5xmerg_allc.tsv
# EPI-120_S32_L005_5xmerg_allc.tsv EPI-188_S21_L003_5xmerg_allc.tsv
# EPI-127_S33_L005_5xmerg_allc.tsv EPI-193_S22_L003_5xmerg_allc.tsv
# EPI-128_S34_L005_5xmerg_allc.tsv EPI-194_S23_L003_5xmerg_allc.tsv
# EPI-135_S35_L005_5xmerg_allc.tsv EPI-199_S24_L003_5xmerg_allc.tsv
# EPI-136_S36_L005_5xmerg_allc.tsv EPI-200_S25_L003_5xmerg_allc.tsv
# EPI-143_S37_L005_5xmerg_allc.tsv EPI-205_S26_L004_5xmerg_allc.tsv
# EPI-145_S38_L005_5xmerg_allc.tsv EPI-206_S27_L004_5xmerg_allc.tsv
# EPI-151_S2_L002_5xmerg_allc.tsv  EPI-208_S28_L004_5xmerg_allc.tsv
# EPI-152_S3_L002_5xmerg_allc.tsv  EPI-209_S29_L004_5xmerg_allc.tsv
# EPI-153_S4_L002_5xmerg_allc.tsv  EPI-214_S30_L004_5xmerg_allc.tsv
# EPI-154_S5_L002_5xmerg_allc.tsv  EPI-215_S31_L004_5xmerg_allc.tsv
# EPI-159_S6_L002_5xmerg_allc.tsv  EPI-220_S32_L004_5xmerg_allc.tsv
# EPI-160_S7_L002_5xmerg_allc.tsv  EPI-221_S33_L004_5xmerg_allc.tsv
# EPI-161_S8_L002_5xmerg_allc.tsv  EPI-226_S34_L004_5xmerg_allc.tsv
# EPI-162_S9_L002_5xmerg_allc.tsv  EPI-227_S35_L004_5xmerg_allc.tsv
# EPI-167_S10_L002_5xmerg_allc.tsv EPI-229_S36_L004_5xmerg_allc.tsv
# EPI-168_S11_L002_5xmerg_allc.tsv EPI-230_S37_L004_5xmerg_allc.tsv
# EPI-169_S12_L002_5xmerg_allc.tsv EPI-41_S38_L005_5xmerg_allc.tsv
# EPI-170_S13_L002_5xmerg_allc.tsv EPI-42_S39_L005_5xmerg_allc.tsv
# EPI-175_S14_L003_5xmerg_allc.tsv EPI-43_S40_L005_5xmerg_allc.tsv
# EPI-176_S15_L003_5xmerg_allc.tsv EPI-44_S41_L005_5xmerg_allc.tsv

# %%
# %%bash
# methylpy DMRfind \
# --allc-files \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-103_S27_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-104_S28_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-111_S29_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-113_S30_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-119_S31_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-120_S32_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-135_S35_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-136_S36_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-127_S33_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-128_S34_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-143_S37_L005_5xmerg_allc.tsv \
# /Users/strigg/Desktop/20200311_DMRfind/EPI-145_S38_L005_5xmerg_allc.tsv \
# --samples EPI-103 EPI-104 EPI-111 EPI-113 EPI-119 EPI-120 EPI-135 EPI-136 EPI-127 EPI-128 EPI-143 EPI-145 \
# --mc-type "CGN" \
# --num-procs 8 \
# --output-prefix Mar11_day10_AllpH_DMR250bp_cov5x \
# --dmr-max-dist 250 \
# --min-num-dms 3 \
# --sample-category 0 0 1 1 2 2 2 2 0 0 1 1
# Out:
# Filtering allc files using 8 node(s).
# Wed Mar 11 15:01:17 2020
#
# Splitting allc files for chromosome Scaffold_01
# Wed Mar 11 15:02:12 2020
#
# Running rms tests for chromosome Scaffold_01
# Wed Mar 11 15:02:17 2020
#
# Splitting allc files for chromosome Scaffold_02
# Wed Mar 11 15:02:17 2020
#
# Ran 25394 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_01_chunk_3.tsv
# Ran 26431 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_01_chunk_5.tsv
# Ran 24174 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_01_chunk_7.tsv
# Ran 26134 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_01_chunk_0.tsv
# Running rms tests for chromosome Scaffold_02
# Wed Mar 11 15:04:49 2020
#
# Splitting allc files for chromosome Scaffold_03
# Wed Mar 11 15:04:49 2020
#
# Ran 25792 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_01_chunk_1.tsv
# Ran 26570 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_01_chunk_6.tsv
# Ran 26831 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_01_chunk_4.tsv
# Ran 26203 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_01_chunk_2.tsv
# Ran 17534 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_02_chunk_2.tsv
# Ran 20044 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_02_chunk_5.tsv
# Ran 19227 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_02_chunk_4.tsv
# Running rms tests for chromosome Scaffold_03
# Wed Mar 11 15:06:42 2020
#
# Splitting allc files for chromosome Scaffold_04
# Wed Mar 11 15:06:42 2020
#
# Ran 19212 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_02_chunk_0.tsv
# Ran 18377 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_02_chunk_7.tsv
# Ran 18991 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_02_chunk_1.tsv
# Ran 21849 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_02_chunk_3.tsv
# Ran 20521 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_02_chunk_6.tsv
# Ran 16392 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_03_chunk_0.tsv
# Ran 16375 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_03_chunk_1.tsv
# Ran 14639 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_03_chunk_6.tsv
# Ran 16287 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_03_chunk_2.tsv
# Running rms tests for chromosome Scaffold_04
# Wed Mar 11 15:08:21 2020
#
# Splitting allc files for chromosome Scaffold_05
# Wed Mar 11 15:08:21 2020
#
# Ran 15653 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_03_chunk_3.tsv
# Ran 15611 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_03_chunk_4.tsv
# Ran 16287 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_03_chunk_5.tsv
# Ran 15600 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_03_chunk_7.tsv
# Ran 16320 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_04_chunk_4.tsv
# Ran 16845 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_04_chunk_3.tsv
# Ran 15686 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_04_chunk_5.tsv
# Running rms tests for chromosome Scaffold_05
# Wed Mar 11 15:09:56 2020
#
# Splitting allc files for chromosome Scaffold_06
# Wed Mar 11 15:09:56 2020
#
# Ran 15822 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_04_chunk_2.tsv
# Ran 17422 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_04_chunk_0.tsv
# Ran 17340 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_04_chunk_1.tsv
# Ran 16809 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_04_chunk_7.tsv
# Ran 16269 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_04_chunk_6.tsv
# Ran 12699 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_05_chunk_0.tsv
# Ran 14593 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_05_chunk_3.tsv
# Running rms tests for chromosome Scaffold_06
# Wed Mar 11 15:11:22 2020
#
# Splitting allc files for chromosome Scaffold_07
# Wed Mar 11 15:11:22 2020
#
# Ran 14408 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_05_chunk_2.tsv
# Ran 15088 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_05_chunk_1.tsv
# Ran 15260 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_05_chunk_4.tsv
# Ran 16443 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_05_chunk_5.tsv
# Ran 16934 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_05_chunk_6.tsv
# Ran 15736 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_05_chunk_7.tsv
# Ran 15065 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_06_chunk_2.tsv
# Ran 14968 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_06_chunk_4.tsv
# Running rms tests for chromosome Scaffold_07
# Wed Mar 11 15:12:50 2020
#
# Splitting allc files for chromosome Scaffold_08
# Wed Mar 11 15:12:50 2020
#
# Ran 15491 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_06_chunk_3.tsv
# Ran 15275 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_06_chunk_0.tsv
# Ran 15225 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_06_chunk_1.tsv
# Ran 14337 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_06_chunk_5.tsv
# Ran 14653 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_06_chunk_6.tsv
# Ran 15454 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_06_chunk_7.tsv
# Ran 9574 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_07_chunk_2.tsv
# Ran 12934 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_07_chunk_0.tsv
# Ran 11041 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_07_chunk_3.tsv
# Ran 11105 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_07_chunk_4.tsv
# Running rms tests for chromosome Scaffold_08
# Wed Mar 11 15:14:01 2020
#
# Splitting allc files for chromosome Scaffold_09
# Wed Mar 11 15:14:01 2020
#
# Ran 12477 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_07_chunk_1.tsv
# Ran 10078 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_07_chunk_7.tsv
# Ran 13425 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_07_chunk_6.tsv
# Ran 11555 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_07_chunk_5.tsv
# Ran 15251 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_08_chunk_2.tsv
# Ran 15347 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_08_chunk_4.tsv
# Ran 15936 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_08_chunk_1.tsv
# Running rms tests for chromosome Scaffold_09
# Wed Mar 11 15:15:31 2020
#
# Splitting allc files for chromosome Scaffold_10
# Wed Mar 11 15:15:31 2020
#
# Ran 16180 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_08_chunk_3.tsv
# Ran 18673 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_08_chunk_0.tsv
# Ran 14505 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_08_chunk_6.tsv
# Ran 17219 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_08_chunk_5.tsv
# Ran 16359 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_08_chunk_7.tsv
# Ran 8638 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_09_chunk_2.tsv
# Ran 10053 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_09_chunk_0.tsv
# Running rms tests for chromosome Scaffold_10
# Wed Mar 11 15:16:37 2020
#
# Splitting allc files for chromosome Scaffold_11
# Wed Mar 11 15:16:37 2020
#
# Ran 11420 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_09_chunk_3.tsv
# Ran 10460 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_09_chunk_4.tsv
# Ran 9574 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_09_chunk_5.tsv
# Ran 10018 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_09_chunk_6.tsv
# Ran 9826 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_09_chunk_1.tsv
# Ran 10030 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_09_chunk_7.tsv
# Ran 13510 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_10_chunk_0.tsv
# Ran 13749 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_10_chunk_1.tsv
# Running rms tests for chromosome Scaffold_11
# Wed Mar 11 15:18:00 2020
#
# Splitting allc files for chromosome Scaffold_12
# Wed Mar 11 15:18:00 2020
#
# Ran 13187 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_10_chunk_3.tsv
# Ran 13394 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_10_chunk_2.tsv
# Ran 14348 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_10_chunk_5.tsv
# Ran 15386 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_10_chunk_4.tsv
# Ran 15482 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_10_chunk_6.tsv
# Ran 13629 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_10_chunk_7.tsv
# Ran 10561 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_11_chunk_1.tsv
# Ran 11234 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_11_chunk_2.tsv
# Running rms tests for chromosome Scaffold_12
# Wed Mar 11 15:19:11 2020
#
# Splitting allc files for chromosome Scaffold_13
# Wed Mar 11 15:19:11 2020
#
# Ran 11462 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_11_chunk_3.tsv
# Ran 14032 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_11_chunk_0.tsv
# Ran 12617 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_11_chunk_5.tsv
# Ran 11282 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_11_chunk_7.tsv
# Ran 12080 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_11_chunk_6.tsv
# Ran 11724 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_11_chunk_4.tsv
# Ran 11115 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_12_chunk_2.tsv
# Running rms tests for chromosome Scaffold_13
# Wed Mar 11 15:20:29 2020
#
# Splitting allc files for chromosome Scaffold_14
# Wed Mar 11 15:20:29 2020
#
# Ran 12243 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_12_chunk_3.tsv
# Ran 14556 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_12_chunk_1.tsv
# Ran 14324 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_12_chunk_0.tsv
# Ran 15385 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_12_chunk_4.tsv
# Ran 13177 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_12_chunk_5.tsv
# Ran 14649 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_12_chunk_6.tsv
# Ran 15169 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_12_chunk_7.tsv
# Ran 11218 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_13_chunk_0.tsv
# Ran 10383 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_13_chunk_1.tsv
# Running rms tests for chromosome Scaffold_14
# Wed Mar 11 15:21:38 2020
#
# Splitting allc files for chromosome Scaffold_15
# Wed Mar 11 15:21:38 2020
#
# Ran 10862 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_13_chunk_2.tsv
# Ran 11770 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_13_chunk_3.tsv
# Ran 10763 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_13_chunk_6.tsv
# Ran 14129 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_13_chunk_4.tsv
# Ran 12368 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_13_chunk_5.tsv
# Ran 10301 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_13_chunk_7.tsv
# Ran 13702 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_14_chunk_2.tsv
# Running rms tests for chromosome Scaffold_15
# Wed Mar 11 15:23:12 2020
#
# Splitting allc files for chromosome Scaffold_16
# Wed Mar 11 15:23:12 2020
#
# Ran 14282 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_14_chunk_3.tsv
# Ran 15227 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_14_chunk_0.tsv
# Ran 15446 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_14_chunk_5.tsv
# Ran 15142 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_14_chunk_1.tsv
# Ran 15723 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_14_chunk_4.tsv
# Ran 15385 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_14_chunk_7.tsv
# Ran 16346 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_14_chunk_6.tsv
# Ran 9934 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_15_chunk_0.tsv
# Running rms tests for chromosome Scaffold_16
# Wed Mar 11 15:24:22 2020
#
# Splitting allc files for chromosome Scaffold_17
# Wed Mar 11 15:24:22 2020
#
# Ran 9313 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_15_chunk_2.tsv
# Ran 11764 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_15_chunk_1.tsv
# Ran 10011 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_15_chunk_4.tsv
# Ran 10489 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_15_chunk_3.tsv
# Ran 9947 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_15_chunk_6.tsv
# Ran 11224 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_15_chunk_5.tsv
# Ran 10722 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_15_chunk_7.tsv
# Ran 6448 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_16_chunk_1.tsv
# Running rms tests for chromosome Scaffold_17
# Wed Mar 11 15:25:11 2020
#
# Splitting allc files for chromosome Scaffold_18
# Wed Mar 11 15:25:11 2020
#
# Ran 8599 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_16_chunk_2.tsv
# Ran 8098 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_16_chunk_3.tsv
# Ran 8091 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_16_chunk_5.tsv
# Ran 7781 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_16_chunk_7.tsv
# Ran 7686 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_16_chunk_6.tsv
# Ran 9652 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_16_chunk_4.tsv
# Ran 9744 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_16_chunk_0.tsv
# Ran 8908 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_17_chunk_0.tsv
# Running rms tests for chromosome Scaffold_18
# Wed Mar 11 15:26:07 2020
#
# Ran 7267 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_17_chunk_7.tsv
# Ran 10128 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_17_chunk_2.tsv
# Ran 10349 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_17_chunk_1.tsv
# Ran 8988 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_17_chunk_5.tsv
# Ran 8546 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_17_chunk_4.tsv
# Ran 10095 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_17_chunk_6.tsv
# Ran 6990 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_18_chunk_0.tsv
# Ran 11448 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_17_chunk_3.tsv
# Ran 6188 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_18_chunk_1.tsv
# Ran 6177 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_18_chunk_3.tsv
# Ran 5695 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_18_chunk_4.tsv
# Ran 6136 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_18_chunk_6.tsv
# Ran 6366 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_18_chunk_5.tsv
# Ran 5903 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_18_chunk_7.tsv
# Ran 7506 root mean square tests. Results in Mar11_day10_AllpH_DMR250bp_cov5x_rms_results_for_Scaffold_18_chunk_2.tsv
# Merging sorted Mar11_day10_AllpH_DMR250bp_cov5x_rms_results.tsv files.
# Wed Mar 11 15:27:23 2020
#
# Begin FDR Correction
# Wed Mar 11 15:30:51 2020
#
# m0 estimate for iteration 0: 1973483
# Histogram FDR correction did not converge. Using the smallest p-value 0.0003333333333333333 as cutoff.
#
# Calculating Residual Cutoff
# Wed Mar 11 15:30:58 2020
#
# Begin Defining Windows
# Wed Mar 11 15:31:10 2020
#
# Adding Methylation Levels
# Wed Mar 11 15:31:54 2020
#
# Done
# Wed Mar 11 15:32:38 2020

# %%
#make a direct

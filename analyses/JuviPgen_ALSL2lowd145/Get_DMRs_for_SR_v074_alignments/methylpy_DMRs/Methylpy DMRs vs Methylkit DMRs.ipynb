# %%
# run call methylation state on .bam

# %%
#copy genome and dedup bams to local directory to process

# %%
# !scp /Volumes/web/seashell/bu-mox/data/geoduck/v074/Pgenerosa_v074.fa \
/Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/

# %%
# !methylpy call-methylation-state --input-file /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/dedup_bams/EPI-205_S26_L004_R1_001_val_1_bismark_bt2_pe.deduplicated.sorted.bam --paired-end True --path-to-output /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs --sample EPI-205 --ref-fasta /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/Pgenerosa_v074.fa --num-procs 8 --min-cov 3
# Out:
# Begin flipping the strand of read 2
# Mon Aug 19 15:37:31 2019
#
# [mpileup] 1 samples in 1 input files

# %%
# !find /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/dedup_bams/*.deduplicated.sorted.bam \
| xargs basename -s .deduplicated.sorted.bam | xargs -I{} methylpy call-methylation-state \
--input-file /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/dedup_bams/{}.deduplicated.sorted.bam \
--paired-end TRUE \
--path-to-output /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs \
--sample {} \
--ref-fasta /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/Pgenerosa_v074.fa \
--num-procs 8 \
--min-cov 3
# Out:
# Begin flipping the strand of read 2
# Mon Aug 19 16:18:25 2019
#
# Input not indexed. Indexing...
# Mon Aug 19 16:20:20 2019
#
# [mpileup] 1 samples in 1 input files
# Begin flipping the strand of read 2
# Mon Aug 19 16:35:38 2019
#
# [mpileup] 1 samples in 1 input files
# Begin flipping the strand of read 2
# Mon Aug 19 16:58:09 2019
#
# [mpileup] 1 samples in 1 input files

# %%
# get DMRs

# %%
cd /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs

# %%
# !methylpy DMRfind \
--allc-files  allc_EPI-205_S26_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-206_S27_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-214_S30_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-215_S31_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-220_S32_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-221_S33_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-226_S34_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-227_S35_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
--samples EPI-205 EPI-206 EPI-214 EPI-215 EPI-220 EPI-221 EPI-226 EPI-227 \
--mc-type "CGN" \
--num-procs 8 \
--min-cov 3 \
--output-prefix DMR500bp_ \
--dmr-max-dist 1000 \
--min-num-dms 3 \
--sample-category 0 0 1 1 1 1 0 0
# Out:
# Filtering allc files using 8 node(s).
# Tue Aug 20 04:56:56 2019
#
# Splitting allc files for chromosome PGA_scaffold1__77_contigs__length_89643857
# Tue Aug 20 04:58:28 2019
#
# Running rms tests for chromosome PGA_scaffold1__77_contigs__length_89643857
# Tue Aug 20 04:58:30 2019
#
# Splitting allc files for chromosome PGA_scaffold2__36_contigs__length_69596280
# Tue Aug 20 04:58:30 2019
#
# Ran 4848 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_7.tsv
# Ran 5595 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_1.tsv
# Ran 5899 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_2.tsv
# Ran 5154 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_0.tsv
# Ran 5651 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_3.tsv
# Running rms tests for chromosome PGA_scaffold2__36_contigs__length_69596280
# Tue Aug 20 04:58:47 2019
#
# Splitting allc files for chromosome PGA_scaffold3__111_contigs__length_57743597
# Tue Aug 20 04:58:47 2019
#
# Ran 6052 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_5.tsv
# Ran 5662 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_4.tsv
# Ran 6033 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_6.tsv
# Ran 3898 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_2.tsv
# Ran 3988 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_4.tsv
# Ran 4303 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_0.tsv
# Ran 4366 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_3.tsv
# Ran 3921 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_7.tsv
# Ran 4170 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_6.tsv
# Ran 4211 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_5.tsv
# Running rms tests for chromosome PGA_scaffold3__111_contigs__length_57743597
# Tue Aug 20 04:59:01 2019
#
# Splitting allc files for chromosome PGA_scaffold4__129_contigs__length_65288255
# Tue Aug 20 04:59:01 2019
#
# Ran 3808 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_1.tsv
# Ran 2868 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_1.tsv
# Ran 3020 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_0.tsv
# Ran 2985 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_6.tsv
# Ran 3339 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_3.tsv
# Running rms tests for chromosome PGA_scaffold4__129_contigs__length_65288255
# Tue Aug 20 04:59:12 2019
#
# Splitting allc files for chromosome PGA_scaffold5__109_contigs__length_67248332
# Tue Aug 20 04:59:12 2019
#
# Ran 3495 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_4.tsv
# Ran 3671 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_2.tsv
# Ran 3678 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_5.tsv
# Ran 3279 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_7.tsv
# Ran 2858 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_5.tsv
# Ran 3189 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_0.tsv
# Ran 3181 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_2.tsv
# Ran 3572 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_3.tsv
# Running rms tests for chromosome PGA_scaffold5__109_contigs__length_67248332
# Tue Aug 20 04:59:22 2019
#
# Splitting allc files for chromosome PGA_scaffold6__104_contigs__length_61759565
# Tue Aug 20 04:59:22 2019
#
# Ran 3428 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_6.tsv
# Ran 3596 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_4.tsv
# Ran 3471 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_7.tsv
# Ran 3767 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_1.tsv
# Ran 2194 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_0.tsv
# Ran 2443 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_2.tsv
# Ran 2706 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_3.tsv
# Ran 2886 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_4.tsv
# Running rms tests for chromosome PGA_scaffold6__104_contigs__length_61759565
# Tue Aug 20 04:59:31 2019
#
# Splitting allc files for chromosome PGA_scaffold7__69_contigs__length_43120122
# Tue Aug 20 04:59:31 2019
#
# Ran 3003 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_1.tsv
# Ran 3057 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_6.tsv
# Ran 3357 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_5.tsv
# Ran 2934 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_7.tsv
# Ran 2761 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_2.tsv
# Ran 2951 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_3.tsv
# Ran 3140 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_4.tsv
# Ran 2528 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_6.tsv
# Ran 2957 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_5.tsv
# Running rms tests for chromosome PGA_scaffold7__69_contigs__length_43120122
# Tue Aug 20 04:59:41 2019
#
# Splitting allc files for chromosome PGA_scaffold8__63_contigs__length_61151155
# Tue Aug 20 04:59:41 2019
#
# Ran 3018 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_0.tsv
# Ran 3103 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_7.tsv
# Ran 2575 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_1.tsv
# Ran 2119 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_4.tsv
# Ran 1953 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_2.tsv
# Ran 2331 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_3.tsv
# Ran 2684 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_0.tsv
# Ran 2536 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_1.tsv
# Running rms tests for chromosome PGA_scaffold8__63_contigs__length_61151155
# Tue Aug 20 04:59:48 2019
#
# Splitting allc files for chromosome PGA_scaffold9__45_contigs__length_38581958
# Tue Aug 20 04:59:48 2019
#
# Ran 2512 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_6.tsv
# Ran 2472 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_5.tsv
# Ran 1867 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_7.tsv
# Ran 3191 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_1.tsv
# Ran 3358 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_2.tsv
# Ran 3145 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_4.tsv
# Ran 3030 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_6.tsv
# Running rms tests for chromosome PGA_scaffold9__45_contigs__length_38581958
# Tue Aug 20 04:59:58 2019
#
# Splitting allc files for chromosome PGA_scaffold10__49_contigs__length_53961475
# Tue Aug 20 04:59:58 2019
#
# Ran 3548 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_5.tsv
# Ran 3565 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_3.tsv
# Ran 2762 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_7.tsv
# Ran 4142 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_0.tsv
# Ran 1700 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_2.tsv
# Ran 2114 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_0.tsv
# Ran 1815 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_3.tsv
# Ran 2184 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_4.tsv
# Ran 2071 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_5.tsv
# Running rms tests for chromosome PGA_scaffold10__49_contigs__length_53961475
# Tue Aug 20 05:00:05 2019
#
# Splitting allc files for chromosome PGA_scaffold11__79_contigs__length_51449921
# Tue Aug 20 05:00:05 2019
#
# Ran 2304 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_1.tsv
# Ran 2017 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_6.tsv
# Ran 2103 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_7.tsv
# Ran 2961 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_1.tsv
# Ran 2933 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_3.tsv
# Ran 2905 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_0.tsv
# Ran 2956 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_5.tsv
# Running rms tests for chromosome PGA_scaffold11__79_contigs__length_51449921
# Tue Aug 20 05:00:16 2019
#
# Splitting allc files for chromosome PGA_scaffold12__71_contigs__length_50438331
# Tue Aug 20 05:00:16 2019
#
# Ran 3380 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_2.tsv
# Ran 3184 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_6.tsv
# Ran 2674 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_7.tsv
# Ran 3800 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_4.tsv
# Ran 2075 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_2.tsv
# Ran 2126 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_3.tsv
# Ran 2261 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_1.tsv
# Ran 2302 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_0.tsv
# Ran 2453 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_5.tsv
# Running rms tests for chromosome PGA_scaffold12__71_contigs__length_50438331
# Tue Aug 20 05:00:24 2019
#
# Splitting allc files for chromosome PGA_scaffold13__52_contigs__length_44396874
# Tue Aug 20 05:00:24 2019
#
# Ran 2090 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_7.tsv
# Ran 2276 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_6.tsv
# Ran 1799 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_4.tsv
# Ran 2158 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_2.tsv
# Ran 2882 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_3.tsv
# Ran 2801 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_6.tsv
# Ran 2733 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_0.tsv
# Running rms tests for chromosome PGA_scaffold13__52_contigs__length_44396874
# Tue Aug 20 05:00:33 2019
#
# Splitting allc files for chromosome PGA_scaffold14__91_contigs__length_45393038
# Tue Aug 20 05:00:33 2019
#
# Ran 3069 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_5.tsv
# Ran 2913 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_4.tsv
# Ran 3011 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_1.tsv
# Ran 3133 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_7.tsv
# Ran 1945 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_1.tsv
# Ran 2346 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_3.tsv
# Ran 2379 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_2.tsv
# Ran 2270 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_0.tsv
# Ran 2222 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_6.tsv
# Ran 2491 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_5.tsv
# Running rms tests for chromosome PGA_scaffold14__91_contigs__length_45393038
# Tue Aug 20 05:00:40 2019
#
# Splitting allc files for chromosome PGA_scaffold15__101_contigs__length_47938513
# Tue Aug 20 05:00:40 2019
#
# Ran 3007 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_4.tsv
# Ran 1974 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_7.tsv
# Ran 2831 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_2.tsv
# Ran 3147 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_0.tsv
# Ran 3420 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_5.tsv
# Running rms tests for chromosome PGA_scaffold15__101_contigs__length_47938513
# Tue Aug 20 05:00:50 2019
#
# Splitting allc files for chromosome PGA_scaffold16__33_contigs__length_31980953
# Tue Aug 20 05:00:50 2019
#
# Ran 3486 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_3.tsv
# Ran 2865 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_7.tsv
# Ran 3375 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_1.tsv
# Ran 3575 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_4.tsv
# Ran 3586 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_6.tsv
# Ran 1833 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_4.tsv
# Ran 1731 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_2.tsv
# Ran 1835 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_3.tsv
# Ran 2049 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_1.tsv
# Ran 1725 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_0.tsv
# Running rms tests for chromosome PGA_scaffold16__33_contigs__length_31980953
# Tue Aug 20 05:00:56 2019
#
# Splitting allc files for chromosome PGA_scaffold17__51_contigs__length_34923512
# Tue Aug 20 05:00:56 2019
#
# Ran 1815 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_6.tsv
# Ran 2096 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_5.tsv
# Ran 1772 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_7.tsv
# Ran 1112 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_1.tsv
# Ran 1435 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_2.tsv
# Ran 1545 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_7.tsv
# Ran 1773 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_3.tsv
# Ran 1583 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_6.tsv
# Ran 1535 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_5.tsv
# Running rms tests for chromosome PGA_scaffold17__51_contigs__length_34923512
# Tue Aug 20 05:01:02 2019
#
# Splitting allc files for chromosome PGA_scaffold18__69_contigs__length_27737463
# Tue Aug 20 05:01:02 2019
#
# Ran 2230 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_4.tsv
# Ran 2164 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_0.tsv
# Ran 1641 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_5.tsv
# Ran 1828 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_0.tsv
# Ran 1342 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_7.tsv
# Running rms tests for chromosome PGA_scaffold18__69_contigs__length_27737463
# Tue Aug 20 05:01:08 2019
#
# Ran 2042 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_4.tsv
# Ran 2253 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_3.tsv
# Ran 2182 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_2.tsv
# Ran 2349 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_1.tsv
# Ran 2192 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_6.tsv
# Ran 1067 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_0.tsv
# Ran 1056 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_1.tsv
# Ran 1109 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_4.tsv
# Ran 1258 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_3.tsv
# Ran 1040 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_5.tsv
# Ran 852 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_6.tsv
# Ran 1608 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_2.tsv
# Ran 1077 root mean square tests. Results in DMR500bp__rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_7.tsv
# Merging sorted DMR500bp__rms_results.tsv files.
# Tue Aug 20 05:01:13 2019
#
# Begin FDR Correction
# Tue Aug 20 05:01:40 2019
#
# m0 estimate for iteration 0: 401015
# Histogram FDR correction did not converge. Using the smallest p-value 0.0003333333333333333 as cutoff.
#
# Calculating Residual Cutoff
# Tue Aug 20 05:01:41 2019
#
# Begin Defining Windows
# Tue Aug 20 05:01:49 2019
#
# Adding Methylation Levels
# Tue Aug 20 05:01:55 2019
#
# Done
# Tue Aug 20 05:01:58 2019

# %%
#call DMS within a 25 bp window

# %%
# !methylpy DMRfind \
--allc-files  allc_EPI-205_S26_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-206_S27_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-214_S30_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-215_S31_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-220_S32_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-221_S33_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-226_S34_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
allc_EPI-227_S35_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
--samples EPI-205 EPI-206 EPI-214 EPI-215 EPI-220 EPI-221 EPI-226 EPI-227 \
--mc-type "CGN" \
--num-procs 8 \
--min-cov 3 \
--output-prefix DMR1000bpMCmax25 \
--mc-max-dist 25 \
--dmr-max-dist 1000 \
--min-num-dms 3 \
--sample-category 0 0 1 1 1 1 0 0
# Out:
# Filtering allc files using 8 node(s).
# Tue Aug 20 06:25:44 2019
#
# Splitting allc files for chromosome PGA_scaffold1__77_contigs__length_89643857
# Tue Aug 20 06:27:16 2019
#
# Running rms tests for chromosome PGA_scaffold1__77_contigs__length_89643857
# Tue Aug 20 06:27:19 2019
#
# Splitting allc files for chromosome PGA_scaffold2__36_contigs__length_69596280
# Tue Aug 20 06:27:19 2019
#
# Ran 7154 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_7.tsv
# Ran 7962 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_2.tsv
# Ran 7796 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_1.tsv
# Ran 7321 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_0.tsv
# Ran 7873 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_3.tsv
# Running rms tests for chromosome PGA_scaffold2__36_contigs__length_69596280
# Tue Aug 20 06:27:49 2019
#
# Splitting allc files for chromosome PGA_scaffold3__111_contigs__length_57743597
# Tue Aug 20 06:27:49 2019
#
# Ran 8266 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_6.tsv
# Ran 8316 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_5.tsv
# Ran 7959 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold1__77_contigs__length_89643857_chunk_4.tsv
# Ran 5876 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_3.tsv
# Ran 5635 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_4.tsv
# Ran 5470 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_2.tsv
# Ran 5774 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_0.tsv
# Running rms tests for chromosome PGA_scaffold3__111_contigs__length_57743597
# Tue Aug 20 06:28:12 2019
#
# Splitting allc files for chromosome PGA_scaffold4__129_contigs__length_65288255
# Tue Aug 20 06:28:12 2019
#
# Ran 5944 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_6.tsv
# Ran 5893 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_5.tsv
# Ran 5577 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_7.tsv
# Ran 4200 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_1.tsv
# Ran 4248 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_0.tsv
# Ran 4969 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_2.tsv
# Ran 4230 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_6.tsv
# Running rms tests for chromosome PGA_scaffold4__129_contigs__length_65288255
# Tue Aug 20 06:28:33 2019
#
# Splitting allc files for chromosome PGA_scaffold5__109_contigs__length_67248332
# Tue Aug 20 06:28:33 2019
#
# Ran 5008 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_5.tsv
# Ran 4589 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_3.tsv
# Ran 4805 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_4.tsv
# Ran 4547 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold3__111_contigs__length_57743597_chunk_7.tsv
# Ran 4592 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_2.tsv
# Ran 4424 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_0.tsv
# Ran 5015 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_3.tsv
# Ran 4303 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_5.tsv
# Running rms tests for chromosome PGA_scaffold5__109_contigs__length_67248332
# Tue Aug 20 06:28:54 2019
#
# Splitting allc files for chromosome PGA_scaffold6__104_contigs__length_61759565
# Tue Aug 20 06:28:54 2019
#
# Ran 5065 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_4.tsv
# Ran 5241 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_1.tsv
# Ran 4777 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_6.tsv
# Ran 3669 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_2.tsv
# Ran 3265 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_0.tsv
# Ran 3967 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_3.tsv
# Ran 3990 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_4.tsv
# Ran 4082 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_1.tsv
# Running rms tests for chromosome PGA_scaffold6__104_contigs__length_61759565
# Tue Aug 20 06:29:14 2019
#
# Splitting allc files for chromosome PGA_scaffold7__69_contigs__length_43120122
# Tue Aug 20 06:29:14 2019
#
# Ran 4810 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold4__129_contigs__length_65288255_chunk_7.tsv
# Ran 4072 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_7.tsv
# Ran 4108 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_6.tsv
# Ran 4537 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold5__109_contigs__length_67248332_chunk_5.tsv
# Ran 4031 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_2.tsv
# Ran 5302 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold2__36_contigs__length_69596280_chunk_1.tsv
# Ran 4392 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_0.tsv
# Ran 4120 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_3.tsv
# Running rms tests for chromosome PGA_scaffold7__69_contigs__length_43120122
# Tue Aug 20 06:29:34 2019
#
# Splitting allc files for chromosome PGA_scaffold8__63_contigs__length_61151155
# Tue Aug 20 06:29:34 2019
#
# Ran 4397 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_4.tsv
# Ran 4133 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_5.tsv
# Ran 3675 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_6.tsv
# Ran 4286 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_7.tsv
# Ran 2869 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_2.tsv
# Ran 3490 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_1.tsv
# Ran 3609 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_0.tsv
# Running rms tests for chromosome PGA_scaffold8__63_contigs__length_61151155
# Tue Aug 20 06:29:51 2019
#
# Splitting allc files for chromosome PGA_scaffold9__45_contigs__length_38581958
# Tue Aug 20 06:29:51 2019
#
# Ran 3035 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_4.tsv
# Ran 3341 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_3.tsv
# Ran 2792 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_7.tsv
# Ran 3422 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_5.tsv
# Ran 3480 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold7__69_contigs__length_43120122_chunk_6.tsv
# Ran 4541 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_1.tsv
# Ran 4761 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_2.tsv
# Running rms tests for chromosome PGA_scaffold9__45_contigs__length_38581958
# Tue Aug 20 06:30:12 2019
#
# Splitting allc files for chromosome PGA_scaffold10__49_contigs__length_53961475
# Tue Aug 20 06:30:12 2019
#
# Ran 4422 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_6.tsv
# Ran 4473 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_4.tsv
# Ran 4861 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_3.tsv
# Ran 5579 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_0.tsv
# Ran 4996 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_5.tsv
# Ran 2888 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_0.tsv
# Ran 2416 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_2.tsv
# Ran 2974 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_4.tsv
# Ran 2610 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_3.tsv
# Ran 2912 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_5.tsv
# Ran 3910 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold8__63_contigs__length_61151155_chunk_7.tsv
# Running rms tests for chromosome PGA_scaffold10__49_contigs__length_53961475
# Tue Aug 20 06:30:27 2019
#
# Splitting allc files for chromosome PGA_scaffold11__79_contigs__length_51449921
# Tue Aug 20 06:30:27 2019
#
# Ran 2876 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_6.tsv
# Ran 3095 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_1.tsv
# Ran 2835 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold9__45_contigs__length_38581958_chunk_7.tsv
# Ran 4183 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_1.tsv
# Ran 4130 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_3.tsv
# Ran 4048 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_0.tsv
# Ran 4719 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_2.tsv
# Running rms tests for chromosome PGA_scaffold11__79_contigs__length_51449921
# Tue Aug 20 06:30:45 2019
#
# Splitting allc files for chromosome PGA_scaffold12__71_contigs__length_50438331
# Tue Aug 20 06:30:45 2019
#
# Ran 4068 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_5.tsv
# Ran 4291 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_6.tsv
# Ran 5096 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_4.tsv
# Ran 3079 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_2.tsv
# Ran 3289 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_0.tsv
# Ran 3698 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold10__49_contigs__length_53961475_chunk_7.tsv
# Ran 3248 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_1.tsv
# Running rms tests for chromosome PGA_scaffold12__71_contigs__length_50438331
# Tue Aug 20 06:31:01 2019
#
# Splitting allc files for chromosome PGA_scaffold13__52_contigs__length_44396874
# Tue Aug 20 06:31:01 2019
#
# Ran 3062 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_3.tsv
# Ran 3351 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_5.tsv
# Ran 3062 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_7.tsv
# Ran 3246 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_6.tsv
# Ran 3153 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_2.tsv
# Ran 3783 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold6__104_contigs__length_61759565_chunk_1.tsv
# Ran 3788 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_0.tsv
# Ran 4147 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_1.tsv
# Running rms tests for chromosome PGA_scaffold13__52_contigs__length_44396874
# Tue Aug 20 06:31:18 2019
#
# Splitting allc files for chromosome PGA_scaffold14__91_contigs__length_45393038
# Tue Aug 20 06:31:18 2019
#
# Ran 4066 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_3.tsv
# Ran 4367 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_5.tsv
# Ran 4148 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_4.tsv
# Ran 3925 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_6.tsv
# Ran 4285 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold12__71_contigs__length_50438331_chunk_7.tsv
# Ran 2906 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_1.tsv
# Ran 3286 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_0.tsv
# Ran 3281 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_2.tsv
# Ran 3132 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_3.tsv
# Running rms tests for chromosome PGA_scaffold14__91_contigs__length_45393038
# Tue Aug 20 06:31:35 2019
#
# Splitting allc files for chromosome PGA_scaffold15__101_contigs__length_47938513
# Tue Aug 20 06:31:35 2019
#
# Ran 3382 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_5.tsv
# Ran 4068 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_4.tsv
# Ran 3244 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_6.tsv
# Ran 2892 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold13__52_contigs__length_44396874_chunk_7.tsv
# Ran 4158 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_2.tsv
# Ran 4694 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_0.tsv
# Running rms tests for chromosome PGA_scaffold15__101_contigs__length_47938513
# Tue Aug 20 06:31:56 2019
#
# Splitting allc files for chromosome PGA_scaffold16__33_contigs__length_31980953
# Tue Aug 20 06:31:56 2019
#
# Ran 4797 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_3.tsv
# Ran 4901 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_5.tsv
# Ran 4773 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_1.tsv
# Ran 4997 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_4.tsv
# Ran 5002 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_6.tsv
# Ran 4224 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold14__91_contigs__length_45393038_chunk_7.tsv
# Ran 2764 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_3.tsv
# Ran 2893 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_1.tsv
# Ran 2669 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_2.tsv
# Ran 2715 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_4.tsv
# Ran 2524 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_0.tsv
# Running rms tests for chromosome PGA_scaffold16__33_contigs__length_31980953
# Tue Aug 20 06:32:12 2019
#
# Splitting allc files for chromosome PGA_scaffold17__51_contigs__length_34923512
# Tue Aug 20 06:32:12 2019
#
# Ran 2587 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold11__79_contigs__length_51449921_chunk_4.tsv
# Ran 3066 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_5.tsv
# Ran 1803 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_1.tsv
# Ran 2618 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_7.tsv
# Ran 2733 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold15__101_contigs__length_47938513_chunk_6.tsv
# Ran 2588 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_3.tsv
# Running rms tests for chromosome PGA_scaffold17__51_contigs__length_34923512
# Tue Aug 20 06:32:22 2019
#
# Splitting allc files for chromosome PGA_scaffold18__69_contigs__length_27737463
# Tue Aug 20 06:32:22 2019
#
# Ran 2168 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_2.tsv
# Ran 2328 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_5.tsv
# Ran 2885 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_4.tsv
# Ran 2329 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_7.tsv
# Ran 2341 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_6.tsv
# Ran 2941 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold16__33_contigs__length_31980953_chunk_0.tsv
# Ran 2716 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_0.tsv
# Running rms tests for chromosome PGA_scaffold18__69_contigs__length_27737463
# Tue Aug 20 06:32:36 2019
#
# Ran 2468 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_5.tsv
# Ran 3209 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_3.tsv
# Ran 3392 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_1.tsv
# Ran 3062 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_2.tsv
# Ran 3048 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_6.tsv
# Ran 2934 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_4.tsv
# Ran 2265 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold17__51_contigs__length_34923512_chunk_7.tsv
# Ran 1665 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_0.tsv
# Ran 1670 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_4.tsv
# Ran 1629 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_1.tsv
# Ran 1325 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_6.tsv
# Ran 1806 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_7.tsv
# Ran 1921 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_3.tsv
# Ran 1690 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_5.tsv
# Ran 2200 root mean square tests. Results in DMR1000bpMCmax25_rms_results_for_PGA_scaffold18__69_contigs__length_27737463_chunk_2.tsv
# Merging sorted DMR1000bpMCmax25_rms_results.tsv files.
# Tue Aug 20 06:32:46 2019
#
# Begin FDR Correction
# Tue Aug 20 06:33:23 2019
#
# m0 estimate for iteration 0: 566773
# Histogram FDR correction did not converge. Using the smallest p-value 0.0003333333333333333 as cutoff.
#
# Calculating Residual Cutoff
# Tue Aug 20 06:33:25 2019
#
# Begin Defining Windows
# Tue Aug 20 06:33:35 2019
#
# Adding Methylation Levels
# Tue Aug 20 06:33:45 2019
#
# Done
# Tue Aug 20 06:33:54 2019

# %%
# create bigwig file
#HAD TO INSTALL WIGTOBIGWIG SOFTWARE
#https://bioconda.github.io/recipes/ucsc-wigtobigwig/README.html
#first had to set my conda channels in the correct order
## ``` 
## conda config --add channels defaults
## conda config --add channels bioconda
## conda config --add channels conda-forge
## ```
#then install the sofware
## ```
## conda install ucsc-wigtobigwig
## ```

# %%
# !find /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs/*_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
| xargs basename -s _L004_R1_001_val_1_bismark_bt2_pe.tsv.gz | xargs -I{} methylpy allc-to-bigwig \
--allc-file {}_L004_R1_001_val_1_bismark_bt2_pe.tsv.gz \
--output-file {}.bw \
--ref-fasta /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/Pgenerosa_v074.fa \
--mc-type CGN \
--bin-size 250

# %%
# !head DMR1000bpMCmax25_rms_results_collapsed.tsv.DMR.bed
# Out:
# chrPGA_scaffold10__49_contigs__length_53961475	24714286	24714301	4
# chrPGA_scaffold11__79_contigs__length_51449921	1542753	1542811	3
# chrPGA_scaffold11__79_contigs__length_51449921	41762167	41762215	5
# chrPGA_scaffold11__79_contigs__length_51449921	46692952	46692987	3
# chrPGA_scaffold13__52_contigs__length_44396874	12130155	12130180	3
# chrPGA_scaffold13__52_contigs__length_44396874	17574534	17574550	3
# chrPGA_scaffold14__91_contigs__length_45393038	7707795	7707940	8
# chrPGA_scaffold14__91_contigs__length_45393038	7715685	7715988	3
# chrPGA_scaffold15__101_contigs__length_47938513	5533042	5533096	10
# chrPGA_scaffold15__101_contigs__length_47938513	18905757	18905806	7

# %%
# !head DMR1000bpMCmax25_rms_results_collapsed.tsv
# Out:
# #chr	start	end	number_of_dms	hypermethylated_samples	hypomethylated_samples	methylation_level_EPI-205	methylation_level_EPI-206	methylation_level_EPI-214	methylation_level_EPI-215	methylation_level_EPI-220	methylation_level_EPI-221	methylation_level_EPI-226	methylation_level_EPI-227
# PGA_scaffold10__49_contigs__length_53961475	24714287	24714301	4	EPI-206,EPI-226,EPI-227	EPI-214,EPI-215	0.6666666666666666	0.9444444444444444	0.25806451612903225	0.3333333333333333	0.36363636363636365	0.6666666666666666	1.0	1.0
# PGA_scaffold11__79_contigs__length_51449921	1542754	1542811	3	EPI-215,EPI-220	EPI-226,EPI-205	0.36363636363636365	0.8333333333333334	NA	1.0	1.0	NA	0.15789473684210525	0.75
# PGA_scaffold11__79_contigs__length_51449921	41762168	41762215	5	EPI-215,EPI-220	EPI-206	NA	0.0967741935483871	0.5333333333333333	1.0	0.8333333333333334	0.45454545454545453	0.3333333333333333	0.3333333333333333
# PGA_scaffold11__79_contigs__length_51449921	46692953	46692987	3	EPI-215,EPI-221	EPI-206	0.3333333333333333	0.0625	0.0	1.0	NA	1.0	0.16666666666666666	NA
# PGA_scaffold13__52_contigs__length_44396874	12130156	12130180	3	EPI-205,EPI-226	EPI-214,EPI-220	0.6666666666666666	0.45454545454545453	0.0	0.16666666666666666	0.0	0.4	0.5714285714285714	0.3333333333333333
# PGA_scaffold13__52_contigs__length_44396874	17574535	17574550	3	EPI-220,EPI-215	EPI-206	NA	0.0	NA	0.6875	1.0	NA	NA	NA
# PGA_scaffold14__91_contigs__length_45393038	7707796	7707940	8	EPI-214,EPI-215	EPI-206	0.6216216216216216	0.034482758620689655	0.8805970149253731	0.9384615384615385	0.6818181818181818	0.75	NA	NA
# PGA_scaffold14__91_contigs__length_45393038	7715686	7715988	3	EPI-214,EPI-215	EPI-205	0.59375	0.0	0.8842105263157894	0.9285714285714286	0.625	0.23809523809523808	NA	1.0
# PGA_scaffold15__101_contigs__length_47938513	5533043	5533096	10	EPI-205,EPI-227	EPI-221	0.75	0.5158371040723982	0.5429447852760736	0.5737704918032787	0.5397727272727273	0.42342342342342343	0.656	0.6946564885496184

# %%
# !head DMR1000bpMCmax25_rms_results_collapsed.tsv.DMS.bed
# Out:
# chrPGA_scaffold10__49_contigs__length_53961475	526	527	CGG;-	0.0003
# chrPGA_scaffold10__49_contigs__length_53961475	708	709	CGC;-	0.0003
# chrPGA_scaffold10__49_contigs__length_53961475	731	732	CGG;+	0.0003
# chrPGA_scaffold10__49_contigs__length_53961475	732	733	CGA;-	0.0003
# chrPGA_scaffold10__49_contigs__length_53961475	734	735	CGA;+	0.0003
# chrPGA_scaffold10__49_contigs__length_53961475	735	736	CGC;-	0.0003
# chrPGA_scaffold10__49_contigs__length_53961475	742	743	CGG;-	0.0003
# chrPGA_scaffold10__49_contigs__length_53961475	758	759	CGA;-	0.0003
# chrPGA_scaffold10__49_contigs__length_53961475	764	765	CGG;-	0.0003
# chrPGA_scaffold10__49_contigs__length_53961475	892	893	CGT;-	0.0003

# %%
#create bedgraphs from coverage files showing these DMRs so I can confirm DMRs are realistic in IGV

# %%
cd /Volumes/web/seashell/bu-mox/scrubbed/0807-004
# Out:
# /Volumes/web/seashell/bu-mox/scrubbed/0807-004

# %%
# %%bash
# for f in *.cov.gz
# do
# zcat < ${f} | awk '{if($5+$6 >=3)print $0}'| /Users/Shared/bioinformatics/bedtools2/bin/intersectBed -a - -b /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs/DMR1000bpMCmax25_rms_results_collapsed.tsv.DMR.bed | awk -F"\t" '{print $1FS$2FS$3FS$4FS$5+$6}' > /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs/${f}.3xcov.DMR.bedgraph
# done
# Out:
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3722	3724	0	0	4
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3722	3724	0	0	4
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	6002	6004	0	0	4
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	6002	6004	0	0	4
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	53	55	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	53	55	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3722	3724	0	0	4
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3722	3724	0	0	4
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	6002	6004	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	6002	6004	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	2508	2510	0	0	4
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	2508	2510	0	0	4
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3722	3724	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3722	3724	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3070	3072	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3070	3072	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3002	3004	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3002	3004	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	6002	6004	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	6002	6004	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3722	3724	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	3722	3724	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	2508	2510	0	0	3
#
# ***** WARNING: File - has inconsistent naming convention for record:
# PGA_scaffold1__77_contigs__length_89643857	2508	2510	0	0	3

# %%
# !head /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs/DMR1000bpMCmax25_rms_results_collapsed.tsv.DMR.bed
# Out:
# chrPGA_scaffold10__49_contigs__length_53961475	24714286	24714301	4
# chrPGA_scaffold11__79_contigs__length_51449921	1542753	1542811	3
# chrPGA_scaffold11__79_contigs__length_51449921	41762167	41762215	5
# chrPGA_scaffold11__79_contigs__length_51449921	46692952	46692987	3
# chrPGA_scaffold13__52_contigs__length_44396874	12130155	12130180	3
# chrPGA_scaffold13__52_contigs__length_44396874	17574534	17574550	3
# chrPGA_scaffold14__91_contigs__length_45393038	7707795	7707940	8
# chrPGA_scaffold14__91_contigs__length_45393038	7715685	7715988	3
# chrPGA_scaffold15__101_contigs__length_47938513	5533042	5533096	10
# chrPGA_scaffold15__101_contigs__length_47938513	18905757	18905806	7

# %%
#need to remov chr

# %%
# %%bash
# sed 's/chr//g' /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs/DMR1000bpMCmax25_rms_results_collapsed.tsv.DMR.bed > /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs/DMR1000bpMCmax25_rms_results_collapsed.tsv.DMRnochr.bed

# %%
#now try to create bedgraph files again

# %%
# %%bash
# for f in *.cov.gz
# do
# zcat < ${f} | awk '{if($5+$6 >=3)print $0}'| /Users/Shared/bioinformatics/bedtools2/bin/intersectBed -a - -b /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs/DMR1000bpMCmax25_rms_results_collapsed.tsv.DMRnochr.bed | awk -F"\t" '{print $1FS$2FS$3FS$4FS$5+$6}' > /Users/strigg/Documents/GitHub/Shelly_Pgenerosa/analyses/JuviPgen_ALSL2lowd145/Get_DMRs_for_SR_v074_alignments/methylpy_DMRs/${f}.3xcov.DMR.bedgraph
# done
